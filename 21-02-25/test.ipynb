# %%
pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.3/11.5 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/11.5 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/11.5 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.5 MB 3.2 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.5 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/11.5 MB 3.5 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("inventory_dataset.csv")
data
# Out:
#     Product_ID Product_Name    Dealer  Stock_Level  Reorder_Threshold  \
# 0          101       Laptop  Dealer_A           50                 20
# 1          102   Smartphone  Dealer_B          120                 50
# 2          103       Tablet  Dealer_C           75                 30
# 3          104   Headphones  Dealer_A          200                100
# 4          105   Smartwatch  Dealer_B           90                 40
# 5          106       Laptop  Dealer_A          155                 75
# 6          107   Smartphone  Dealer_B          171                 84
# 7          108       Tablet  Dealer_C          187                 93
# 8          109   Headphones  Dealer_A          203                102
# 9          110   Smartwatch  Dealer_B          219                111
# 10         111       Laptop  Dealer_A          235                120
# 11         112   Smartphone  Dealer_B          251                129
# ...

# %%
data.describe()
# Out:
#        Product_ID  Stock_Level  Reorder_Threshold  Sales_Last_Month
# count   39.000000    39.000000          39.000000         39.000000
# mean   120.000000   379.000000         201.000000        309.000000
# std     11.401754   183.206814         103.008686        160.246521
# min    101.000000    50.000000          20.000000         25.000000
# 25%    110.500000   227.000000         115.500000        176.000000
# 50%    120.000000   379.000000         201.000000        309.000000
# 75%    129.500000   531.000000         286.500000        442.000000
# max    139.000000   683.000000         372.000000        575.000000
